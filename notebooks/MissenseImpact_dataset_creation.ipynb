# %% [markdown]
# <a href="https://colab.research.google.com/github/BilalAsifB/MissenseImpact-FYP/blob/main/notebooks/MissenseImpact_dataset_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch pandas numpy transformers cyvcf2 requests --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.1 MB/s eta 0:00:00

# %%
# !rm -rf /content/MissenseImpact-FYP

# %%
# !git clone https://github.com/BilalAsifB/MissenseImpact-FYP.git
# Out:
# Cloning into 'MissenseImpact-FYP'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 379 (delta 34), reused 20 (delta 6), pack-reused 304 (from 1)
# Receiving objects: 100% (379/379), 30.19 MiB | 43.54 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %%
cd MissenseImpact-FYP
# Out:
# /content/MissenseImpact-FYP

# %%
# !ls
# Out:
# configs  docs	     LICENSE  notebooks       README.md  tests	   tuning
# data	 evaluation  model    pyproject.toml  scripts	 training

# %%
# !PYTHONPATH=. python scripts/build_training_data.py \
    --gnomad_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/gnomad/gnomad_pure_sas_annotated/ \
    --sg10k_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/sg10k/sg10k_annotated/ \
    --indigen_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/indigen/indigen_annotated/ \
    --thousandg_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/1k/1k_annotated/ \
    --output_dir /content/drive/MyDrive/missense-dataset/ \
    --seq_cache /content/drive/MyDrive/missense-dataset/cache/uniprot_seqs.json \
    --gene_cache /content/drive/MyDrive/missense-dataset/cache/gene_uniprot.json \
    --checkpoint_dir /content/drive/MyDrive/missense-dataset/cache/vcf_checkpoints
# Out:
# 2026-03-29 13:39:46,735 INFO  VCF checkpoint directory: /content/drive/MyDrive/missense-dataset/cache/vcf_checkpoints
# 2026-03-29 13:39:46,736 INFO  [gnomad  ] Parsing gnomad_chr1_pure_sas_annotated_mane.vcf.gz
# 2026-03-29 13:51:59,864 INFO  [gnomad  ] 3486330 total → 118661 MANE-select missense kept
# 2026-03-29 13:52:01,330 INFO  [gnomad  ] chr1 — checkpoint saved (118661 variants → gnomad_chr1.parquet)
# 2026-03-29 13:52:01,332 INFO  [gnomad  ] Parsing gnomad_chr2_pure_sas_annotated_mane.vcf.gz
# 2026-03-29 14:04:10,211 INFO  [gnomad  ] 3608392 total → 87011 MANE-select missense kept
# 2026-03-29 14:04:11,413 INFO  [gnomad  ] chr2 — checkpoint saved (87011 variants → gnomad_chr2.parquet)
# 2026-03-29 14:04:11,417 INFO  [gnomad  ] Parsing gnomad_chr3_pure_sas_annotated_mane.vcf.gz
# 2026-03-29 14:14:36,783 INFO  [gnomad  ] 2956189 total → 66573 MANE-select missense kept
# 2026-03-29 14:14:37,402 INFO  [gnomad  ] chr3 — checkpoint saved (66573 variants → gnomad_chr3.parquet)
# ...

# %%
# Sanity check

# !PYTHONPATH=. python scripts/build_training_data.py \
#     --gnomad_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/gnomad/gnomad_pure_sas_annotated/ \
#     --sg10k_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/sg10k/sg10k_annotated/ \
#     --indigen_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/indigen/indigen_annotated/ \
#     --thousandg_dir /content/drive/MyDrive/FYP_DATA/DATA/annotated_data_mane/1k/1k_annotated/ \
#     --output_dir /content/drive/MyDrive/missense-dataset/ \
#     --seq_cache /content/drive/MyDrive/missense-dataset/cache/uniprot_seqs.json \
#     --gene_cache /content/drive/MyDrive/missense-dataset/cache/gene_uniprot.json \
#     --chromosomes chr22 \
#     --checkpoint_dir /content/drive/MyDrive/missense-dataset/cache/vcf_checkpoints
# Out:
# 2026-03-29 13:26:49,573 INFO  VCF checkpoint directory: /content/drive/MyDrive/missense-dataset/cache/vcf_checkpoints
# 2026-03-29 13:26:52,898 INFO  [gnomad  ] Parsing gnomad_chr22_pure_sas_annotated_mane.vcf.gz
# 2026-03-29 13:29:25,812 INFO  [gnomad  ] 643676 total → 23865 MANE-select missense kept
# 2026-03-29 13:29:26,185 INFO  [gnomad  ] chr22 — checkpoint saved (23865 variants → gnomad_chr22.parquet)
# 2026-03-29 13:29:26,186 INFO  gnomad  : 23865 variants total
# 2026-03-29 13:29:26,728 INFO  [sg10k   ] Parsing sg10k_chr22_SAS_annotated_mane.vcf.gz
# 2026-03-29 13:32:33,656 INFO  [sg10k   ] 1339154 total → 12513 MANE-select missense kept
# 2026-03-29 13:32:33,798 INFO  [sg10k   ] chr22 — checkpoint saved (12513 variants → sg10k_chr22.parquet)
# 2026-03-29 13:32:33,798 INFO  sg10k   : 12513 variants total
# 2026-03-29 13:32:34,233 INFO  [indigen ] Parsing indigen_annotated_mane.vcf.gz
# 2026-03-29 13:34:37,918 INFO  [indigen ] 194032 total → 1744 MANE-select missense kept
# ...
